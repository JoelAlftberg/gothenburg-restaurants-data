# %% [markdown]
# # 1. Getting the data

# %% [markdown]
# ### The main code for sending an API request

# %%
import requests, json
from secretfile import api_key

origin_location = "57.70867542111475,11.973303298399806"
radius_in_meters = 1000
query_string = "pasta"

url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={query_string}&type=restaurant&location={origin_location}&radius={radius_in_meters}&key={api_key}"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
response.raise_for_status()

print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "Aap_uECSuD0r8MyHI9B-1v04zNNUyZWzvsC97fCNut2NGXUfN-CWX8miKggkyqD8ZP8d6ZwbOa7bur58Q3ZiPb1xW5EsLVxyRqTEe63nbmjd1rtv_T48ZSaEdlFakM3kWwFx6XVVU5BuO8LFn7D9ICktyZvx9TgT3YKuWAt0CyZq0QfE-j81p1TwHwsCmkmB1kklUoz9AdM8dx4R7nJbKpxQH_eqg-hT26uWcF4XJtA1pXg13qhE_MLqPpBlzOLa3SXfM87MYbq0U8oTNsPi646I6OiIt1chgocb-NroBXESuhAQ8xYYkeX9GCnDscSdIo8J-MLxl7cXsPhy0ndPWNOeTR1Fhk9H49WlXMXbFkHaWL2FJZbXrfmNDXoDOTs7TWN1nc3LC75-Q-LakQlAEY7Tzo40YTko2Gi-c59pHx6li6B6hbcuVtBnNZ9GT-EJ7MRj6qHCMcUmntjb",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Östra Hamngatan 35, 411 10 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.7052047,
#                "lng" : 11.9684766
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70657287989273,
#                   "lng" : 11.96994152989272
#                },
#                "southwest" : {
#                   "lat" : 57.70387322010728,
#                   "lng" : 11.96724187010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Vapiano Kungsport",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/110501028983286072339\"\u003eAaron Dr\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uECfVw75GoBoIc8TCfZF-53oiGAvofqiNaVOS3ucxmpDhd80jPBG67gPaiyjgN0MPqJuMzQWj3p5VOmja8EEhhf1ou4mbJXTYBkboE0OmBtKkWSVj_4rahJKoU9yuJzAHnObL2XetrYoZCr217dyA-3enX171mHVloZv7xVzcPM2IVz6",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJE5T9r2XzT0YRhHGvrwBQcos",
#          "plus_code" : {
#             "compound_code" : "PX49+39 Gothenburg",
#             "global_code" : "9F9HPX49+39"
#          },
#          "price_level" : 2,
#          "rating" : 3.5,
#          "reference" : "ChIJE5T9r2XzT0YRhHGvrwBQcos",
#          "types" : [ "bar", "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 2621
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Södra Vägen 26, 412 54 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.6979349,
#                "lng" : 11.9836588
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.69922772989272,
#                   "lng" : 11.98491327989272
#                },
#                "southwest" : {
#                   "lat" : 57.69652807010727,
#                   "lng" : 11.98221362010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Vino Pasta Due",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/114121496383942499348\"\u003eSonia Baroudi\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEDx4FRHU0t_f32iY1IvqqYeJ_3TY9x434KsnGTi_mYs2pmpAjYIOAEBdHDGjeoM4UDono8HGjcqzNtzLhNWrdZ8cszc5soHaZoizhreu-YXggJLgMO18jr7aordpUvWFdguCYi9m54cFvx-QKGzmFEvVQyEPzM4dOdxLd1IekaV_nj1",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJj7ps93bzT0YRGLSi0h4fGLc",
#          "plus_code" : {
#             "compound_code" : "MXXM+5F Gothenburg",
#             "global_code" : "9F9HMXXM+5F"
#          },
#          "price_level" : 2,
#          "rating" : 3.8,
#          "reference" : "ChIJj7ps93bzT0YRGLSi0h4fGLc",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 369
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Kungsgatan 12, 411 19 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.703275,
#                "lng" : 11.9594778
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70458032989272,
#                   "lng" : 11.96084337989272
#                },
#                "southwest" : {
#                   "lat" : 57.70188067010728,
#                   "lng" : 11.95814372010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Nonna",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 1001,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/103121020254058454411\"\u003eLiv W\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAnHAgCwakzVljtMazFvAtGBoTfa3xip8VcPDfqd3gPPB5oDI-UEuceQuAVDWHy0WhkjaBRNwhKCQ91_UNzgfoH-h5cuiUqWNNZK-R9xy8-f_60ROD_wVwfv7XtX49_jBr4HtK9S8XG3BQUpz1zPe-YJ8E1XayzQoQQMbcBsmJD0a3S",
#                "width" : 1334
#             }
#          ],
#          "place_id" : "ChIJi9_ffGjzT0YR9WzaujNT7xs",
#          "plus_code" : {
#             "compound_code" : "PX35+8Q Gothenburg",
#             "global_code" : "9F9HPX35+8Q"
#          },
#          "price_level" : 2,
#          "rating" : 4.1,
#          "reference" : "ChIJi9_ffGjzT0YR9WzaujNT7xs",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 1401
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Vasaplatsen 4, 411 34 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.6999333,
#                "lng" : 11.9696429
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70124147989272,
#                   "lng" : 11.97089612989272
#                },
#                "southwest" : {
#                   "lat" : 57.69854182010728,
#                   "lng" : 11.96819647010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Enoteca del Signore",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 2268,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/112174973672097666145\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEBsBkKj6KEPBhVuB-i9d7cZWUJcJzDlhsyHbTM1Ofyj8kUCrbM8eVQL9YVpZsMIPD7s5FruQTYff5ogaT5N2-OCMKtiqQKwvPKzBN1yWkT4mhECGAD_CI1p9ee1UGy2wJacYxS1i32nsOErd83qB1hDSw4G5kiruwXb57kOuuiYYrIj",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJodVoNW7zT0YRDuH4wM5AT9w",
#          "plus_code" : {
#             "compound_code" : "MXX9+XV Gothenburg",
#             "global_code" : "9F9HMXX9+XV"
#          },
#          "price_level" : 2,
#          "rating" : 4,
#          "reference" : "ChIJodVoNW7zT0YRDuH4wM5AT9w",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 427
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Sten Sturegatan 19, 412 52 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.69989260000001,
#                "lng" : 11.9846491
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70130052989273,
#                   "lng" : 11.98613627989272
#                },
#                "southwest" : {
#                   "lat" : 57.69860087010728,
#                   "lng" : 11.98343662010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "La Terrazza",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3744,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/109644929474575929081\"\u003eLa Terrazza\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEDN43thcjAuzK89Yg4QnMiRhTbIhekoQdeFk4tPRwISOTlSCz6GgrcZvSPzN3n-9A33WAFlyWU5Dr1_d1b_8jo05T2sm3hoRSXMZ4mCyQpv2Ig3FReHfHQj3wkKvCQjJjgC8xj6hu0bA5zXyYbI-Qg1PtomRWzt9mYziQcJAs-IFzxV",
#                "width" : 5616
#             }
#          ],
#          "place_id" : "ChIJhTZEC3fzT0YR0fbyPLwHwco",
#          "plus_code" : {
#             "compound_code" : "MXXM+XV Gothenburg",
#             "global_code" : "9F9HMXXM+XV"
#          },
#          "price_level" : 2,
#          "rating" : 3.5,
#          "reference" : "ChIJhTZEC3fzT0YR0fbyPLwHwco",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 658
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Sten Sturegatan 17, 412 52 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.700014,
#                "lng" : 11.984284
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70144597989272,
#                   "lng" : 11.98582822989272
#                },
#                "southwest" : {
#                   "lat" : 57.69874632010728,
#                   "lng" : 11.98312857010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Trattoria da Pasquale",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 2322,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/107929877844371827658\"\u003eAlejandro Contreras\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAOBdYUQDtfPgYPI8J9h3qZgUfJf8msJrgcsMxZshic6ETiYRK8ldZlO7k2iEx1JkpuAiai4mUXIXPi3tbji1dNL09l2v4yHoOSxV1fjxeo-SNYoWC1Bt_TxN7SOtxbKSXYd8kkZ1DjrLfN2DFC8Tps8jyRh8fjeb95C88LwuTJuFbG",
#                "width" : 4128
#             }
#          ],
#          "place_id" : "ChIJj4hOc3fzT0YR86HFyik2zhE",
#          "plus_code" : {
#             "compound_code" : "PX2M+2P Gothenburg",
#             "global_code" : "9F9HPX2M+2P"
#          },
#          "price_level" : 2,
#          "rating" : 3.9,
#          "reference" : "ChIJj4hOc3fzT0YR86HFyik2zhE",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 514
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Kungsgatan 6B, 411 19 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.7029728,
#                "lng" : 11.9576764
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70428992989272,
#                   "lng" : 11.95904262989272
#                },
#                "southwest" : {
#                   "lat" : 57.70159027010727,
#                   "lng" : 11.95634297010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Ristorante Fontana di Trevi",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3636,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/109534400994220454897\"\u003eRistorante Fontana di Trevi\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEDMAnKQ_n9pr-TVXzcyXSvDLVlgfKtYC5K95zDT-MscNpns3zRHcHxdaWtb2Pl7GHbDgDV6Fd7gzYO_doqi0vK8SXlIPwe3hsqqcAhNNRTf48iwRBchMf7EUoBM8YcuzcxKNaLZtyXNPcZN1ptJrVXyGgCDuCCpqr1KyGMWHvm6RhaU",
#                "width" : 5154
#             }
#          ],
#          "place_id" : "ChIJmVrCFGjzT0YRDWGxZaSoYgI",
#          "plus_code" : {
#             "compound_code" : "PX35+53 Gothenburg",
#             "global_code" : "9F9HPX35+53"
#          },
#          "price_level" : 2,
#          "rating" : 4.3,
#          "reference" : "ChIJmVrCFGjzT0YRDWGxZaSoYgI",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 492
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Kungsportsavenyen 4, 411 36 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.7016415,
#                "lng" : 11.9738477
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70291822989272,
#                   "lng" : 11.97501877989272
#                },
#                "southwest" : {
#                   "lat" : 57.70021857010727,
#                   "lng" : 11.97231912010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "La Gondola",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/115617877053418759427\"\u003eJeton Jegeni\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEBHrSlR3aip4N0jH1eNcZvmwnPPlLzvZHR6LrDlYYDBP97QqcoVj_3UsRnDfOYmA3zqgeCaId6GmWxMEYkSotp5hQ26Noc_kZEog3C7N3nvIy4A9ePpjUFgZVjJCzz_MTkp-XRvDtLX57Gy96z60sKVa-6KpZLKxd3i71Wy7qLjQA23",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJX2ZbGnDzT0YRYqGTEg0szPA",
#          "plus_code" : {
#             "compound_code" : "PX2F+MG Gothenburg",
#             "global_code" : "9F9HPX2F+MG"
#          },
#          "price_level" : 2,
#          "rating" : 3.9,
#          "reference" : "ChIJX2ZbGnDzT0YRYqGTEg0szPA",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 991
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Västra Hamngatan 20, 411 17 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.7032672,
#                "lng" : 11.9646369
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70459587989271,
#                   "lng" : 11.96584047989272
#                },
#                "southwest" : {
#                   "lat" : 57.70189622010727,
#                   "lng" : 11.96314082010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Sorellina",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/115617877053418759427\"\u003eJeton Jegeni\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEB_dlqK8GwEC98xzM01Eki1uLw6-zPU7KUCO1w8LpUGN_flY5sSYyXXcCy1vuMzuJBil6nC6U5x_OWKGrLpt07PWJoTLS3BPd8_Vs5enWY9cr75fHmf6_jWqCC9UV_W3PxLyAkKVgbMnIEp7Tcfhf6y-N4SllZm41aikwUB_MQljL47",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJGWdHVW_zT0YRqlO3AZGvUgo",
#          "plus_code" : {
#             "compound_code" : "PX37+8V Gothenburg",
#             "global_code" : "9F9HPX37+8V"
#          },
#          "price_level" : 2,
#          "rating" : 4.2,
#          "reference" : "ChIJGWdHVW_zT0YRqlO3AZGvUgo",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 383
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Magasinsgatan 3, 411 18 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.7046748,
#                "lng" : 11.9617598
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70603542989272,
#                   "lng" : 11.96317737989272
#                },
#                "southwest" : {
#                   "lat" : 57.70333577010728,
#                   "lng" : 11.96047772010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Magazzino Ristorante Italiano",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 2988,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/118224192173262861029\"\u003eCarmelo Lopes\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uECCWEInaq1rKjyd3NurwH_FKVRtO4CcH2KulyZ0mXWAW99n-4GmL_FbIsgkktnxQ-m0mevZxwRu13KD5O5JvcPII4j5eWC1SCzf5GlSWLMfS_nlv7vZlTzMxUHxeclV8VqRE9EwH4Oxeid4apzp1hh0800vWuAqDuLKead6VwhzaOmR",
#                "width" : 5312
#             }
#          ],
#          "place_id" : "ChIJh7FFOmbzT0YR4hIrHDBJhSA",
#          "plus_code" : {
#             "compound_code" : "PX36+VP Gothenburg",
#             "global_code" : "9F9HPX36+VP"
#          },
#          "price_level" : 2,
#          "rating" : 4.4,
#          "reference" : "ChIJh7FFOmbzT0YR4hIrHDBJhSA",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 943
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Kungsportsavenyen 1, 411 36 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.701683,
#                "lng" : 11.9727232
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70306692989273,
#                   "lng" : 11.97415487989272
#                },
#                "southwest" : {
#                   "lat" : 57.70036727010729,
#                   "lng" : 11.97145522010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Olivia Avenyn",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3456,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/106653954209791995865\"\u003eRafael Chagas\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEA7oimOWEGygj4tzCL1jNNdNS0dGVq8SKJhF-LhQBeS7LYzG2YvdNm86Us8UL8pi4Zx2fTauPuayPEbELKTch2T5OXod3hUwEKKMcGqid6el0w0LuZ_Y0OnR9oJGs1Rvx7wtCPLdz3Sl6BO57AAWazbw4tYsS2I4JpdpOtAl1HHgzWp",
#                "width" : 4608
#             }
#          ],
#          "place_id" : "ChIJFfJyBODzT0YRvXN0qNkwEeI",
#          "plus_code" : {
#             "compound_code" : "PX2F+M3 Gothenburg",
#             "global_code" : "9F9HPX2F+M3"
#          },
#          "rating" : 4.2,
#          "reference" : "ChIJFfJyBODzT0YRvXN0qNkwEeI",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 729
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Nordenskiöldsgatan 25, 413 09 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.6927266,
#                "lng" : 11.9492459
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.69402617989272,
#                   "lng" : 11.95059972989272
#                },
#                "southwest" : {
#                   "lat" : 57.69132652010728,
#                   "lng" : 11.94790007010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Pasta Haus",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4160,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/102551008498918127338\"\u003eJoana Rodrigues\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEDY41wQEKvCPiPVutdQuyFkByfyM7i9PZXuy2S2lMeV0UnM7ZrhEdjtSrEAZk613YdTzDc0_xu_R4SvgWd0Fp2v6oAutm2w0iMg_F7PUFozLruv2Y4rRpmTNGSF42OSMPvEQImHE-kFy2QUBuGtPa3yASD6nKX1enBgHxKPS7Yq4pwt",
#                "width" : 3120
#             }
#          ],
#          "place_id" : "ChIJGeUk8D_zT0YRj6GBdP7ldt4",
#          "plus_code" : {
#             "compound_code" : "MWVX+3M Gothenburg",
#             "global_code" : "9F9HMWVX+3M"
#          },
#          "price_level" : 2,
#          "rating" : 3.9,
#          "reference" : "ChIJGeUk8D_zT0YRj6GBdP7ldt4",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 701
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Södra Vägen 2, 412 54 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.69958629999999,
#                "lng" : 11.9803276
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70086987989271,
#                   "lng" : 11.98156307989272
#                },
#                "southwest" : {
#                   "lat" : 57.69817022010727,
#                   "lng" : 11.97886342010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Pasta +",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/103069426228933357950\"\u003eFredrik Engdahl\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEASQcKxfpxzHk3jQukBykhglE4PTn75UKcOoKeYYfKek9SVxUkC_nnif3Tgr-AaAxQ6yxmI0MdlQ24osC9TaTfSXEAnXOHsWY-HeBbN8RgMSCnR2OYhOx5eZvYN5W5-FwdxdMpyS3wvwdSZs9M1je5AUp-bpMhwNzsYrCrT7spC_13S",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJt3wW03DzT0YRiLNJ38Ii1HM",
#          "plus_code" : {
#             "compound_code" : "MXXJ+R4 Gothenburg",
#             "global_code" : "9F9HMXXJ+R4"
#          },
#          "price_level" : 2,
#          "rating" : 3.9,
#          "reference" : "ChIJt3wW03DzT0YRiLNJ38Ii1HM",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 855
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Götgatan 10, 411 05 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.70747429999999,
#                "lng" : 11.9697862
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70906132989273,
#                   "lng" : 11.97129707989272
#                },
#                "southwest" : {
#                   "lat" : 57.70636167010728,
#                   "lng" : 11.96859742010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Pasta Prego",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 4128,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/117385933964280806246\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAgulgurPtw2NqriPnkN1p8lR-hD2s4ncbGd5Joos7DQxGbSKuMhEee1B7StxpdRk3ueWJYr3fjEcDvQJ2KMY-iNWpDzDZTg9cSzX3xXEUrTZYKSj7v0fL-w_MghRMHrG8QfC2GK_t3p3lKZMXWRV9BRWNrfpTEe-XoOA6vdzcbPvK6",
#                "width" : 2322
#             }
#          ],
#          "place_id" : "ChIJz8JZdWTzT0YRu-IcHZhpzfw",
#          "plus_code" : {
#             "compound_code" : "PX49+XW Gothenburg",
#             "global_code" : "9F9HPX49+XW"
#          },
#          "price_level" : 2,
#          "rating" : 3.6,
#          "reference" : "ChIJz8JZdWTzT0YRu-IcHZhpzfw",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 659
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Kungstorget 12, 411 10 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.7038185,
#                "lng" : 11.9686835
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70516832989271,
#                   "lng" : 11.97003332989272
#                },
#                "southwest" : {
#                   "lat" : 57.70246867010727,
#                   "lng" : 11.96733367010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Aldardo",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 3008,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/110761010997396109821\"\u003eIvano Alegiani\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEADHBGX9zBAixN_DO2fuUTzrIdaiWKV5v7neT-JvW0emvUaSV_8liyNdZoEn0pc6GH2lMeNaA_77v1EttH9DDpJbKXdP9yIQ43RfQSpY34nWOkXTyd16EBMWrd8WMomZ7A8w3orqiQojN6NRwscNLdLI7EVpjwe98rA4UogJET05L0",
#                "width" : 4016
#             }
#          ],
#          "place_id" : "ChIJ1Y_nnGXzT0YRkJt9bXrTjLQ",
#          "plus_code" : {
#             "compound_code" : "PX39+GF Gothenburg",
#             "global_code" : "9F9HPX39+GF"
#          },
#          "price_level" : 2,
#          "rating" : 4.1,
#          "reference" : "ChIJ1Y_nnGXzT0YRkJt9bXrTjLQ",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 555
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Nordenskiöldsgatan 21, 413 09 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.692739,
#                "lng" : 11.9501441
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.69404412989272,
#                   "lng" : 11.95150267989272
#                },
#                "southwest" : {
#                   "lat" : 57.69134447010727,
#                   "lng" : 11.94880302010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "PICCOLA ITALIA (Ristorante Italiano)",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 800,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/100960856991506804565\"\u003ePiccola Italia\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEBGHj1t7ztDcfo1eAv-LQ1Xits3L-RSKvttPv4lOWPyo9l1TGMVpRSSq6jrF547-w9BjpRIKz7wggUPWohTgTWLDUDAjPGh6mn5dDNWpAmN-SNSeHHOWiDrbAuMHxBBJfMSkDrAjFN9TC90GluyhabbevB8kHx3ycrxOHEWnXUJBkWk",
#                "width" : 1200
#             }
#          ],
#          "place_id" : "ChIJfZ8d_T_zT0YRlA1oUepAoSo",
#          "plus_code" : {
#             "compound_code" : "MXV2+33 Gothenburg",
#             "global_code" : "9F9HMXV2+33"
#          },
#          "price_level" : 2,
#          "rating" : 4.3,
#          "reference" : "ChIJfZ8d_T_zT0YRlA1oUepAoSo",
#          "types" : [ "bar", "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 428
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Odinsplatsen 3A, 411 02 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.7098767,
#                "lng" : 11.9856202
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.71118872989272,
#                   "lng" : 11.98682472989272
#                },
#                "southwest" : {
#                   "lat" : 57.70848907010728,
#                   "lng" : 11.98412507010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Fornello",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/109143808828349997434\"\u003eBjarne Hedén\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEA2q-XaOAOX-uhchbRc4X-bb0Km9Y_t2ALURQaKUH5_t9TJGE6zOijHBtJBpVqPH2ASs-0-Tsz0DB5iGy5o-l6EU4pganWpVT5eU5ZQBaWodP8Lf9-DJMlySuWR2H4Pw9qRcZaGrf4Mls4MVsKBQBhtttCpnVq6U0K9GMj4kaxNLngp",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJyZvZhn7zT0YRGgfNr9gb2Fw",
#          "plus_code" : {
#             "compound_code" : "PX5P+X6 Gothenburg",
#             "global_code" : "9F9HPX5P+X6"
#          },
#          "price_level" : 2,
#          "rating" : 4.1,
#          "reference" : "ChIJyZvZhn7zT0YRGgfNr9gb2Fw",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 323
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Engelbrektsgatan 55, 412 52 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.7000828,
#                "lng" : 11.980961
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70148972989273,
#                   "lng" : 11.98222447989272
#                },
#                "southwest" : {
#                   "lat" : 57.69879007010729,
#                   "lng" : 11.97952482010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Mr. Antipasti",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/107367511414516822908\"\u003eVilde Lauritzen\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAFdc7sTrWgkvyyeGgHT0BmTdXlTe7KWEeGC9yNDRRaS2FS9J-bzXaNXLwjl885cNDwl8iFhRdU-y-BS6f0Sp_-6TKCfinZnWGlEeRMtu1fYnx_oGMpSPGWpS0r3P-OxjgNMdEVjizViLMDyqvDKDWBg8tJNA5kNWBaQ38jKvC3ZMYJ",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJpzOONHfzT0YR-TpHeL_0fVc",
#          "plus_code" : {
#             "compound_code" : "PX2J+29 Gothenburg",
#             "global_code" : "9F9HPX2J+29"
#          },
#          "price_level" : 2,
#          "rating" : 4.2,
#          "reference" : "ChIJpzOONHfzT0YR-TpHeL_0fVc",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 171
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Kungstorget 13, 411 10 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.70370740000001,
#                "lng" : 11.9687689
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70503062989273,
#                   "lng" : 11.97004372989272
#                },
#                "southwest" : {
#                   "lat" : 57.70233097010728,
#                   "lng" : 11.96734407010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Italiensk Restaurang Göteborg",
#          "place_id" : "ChIJiQ7MgmXzT0YR-kN3Cg4zukk",
#          "plus_code" : {
#             "compound_code" : "PX39+FG Gothenburg",
#             "global_code" : "9F9HPX39+FG"
#          },
#          "rating" : 4,
#          "reference" : "ChIJiQ7MgmXzT0YR-kN3Cg4zukk",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 1
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Brämaregatan 18, 417 04 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.71872379999999,
#                "lng" : 11.9464892
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.72007362989272,
#                   "lng" : 11.94783902989272
#                },
#                "southwest" : {
#                   "lat" : 57.71737397010727,
#                   "lng" : 11.94513937010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Kvilles Pastahouse",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3840,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/107807928322792859377\"\u003eAdrian Wettergren\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uECP8EUIaxJNFJztPwh2f6vlbRCr8DEyQqH_uGOnR43DCRrEXXsaghhZdUvBl3wA1W4YKFkTRhIMWIXWww1pnmvWWZhNQwGxFe7SuAJlRN8ybSLhIWzRCcnsBTx4ubCxSHlwhcxxo4cs_OUBelRjtwATD2RmOAtE22_TCmLsk1F9YoVB",
#                "width" : 2160
#             }
#          ],
#          "place_id" : "ChIJryqRxaf0T0YRh54kHdyhbEA",
#          "plus_code" : {
#             "compound_code" : "PW9W+FH Gothenburg",
#             "global_code" : "9F9HPW9W+FH"
#          },
#          "price_level" : 1,
#          "rating" : 4.1,
#          "reference" : "ChIJryqRxaf0T0YRh54kHdyhbEA",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 149
#       }
#    ],
#    "status" : "OK"
# }

# %% [markdown]
# ### Formatting the data we just got

# %% [markdown]
# We want to write our results to a file temporarily, we will make this a .csv file in the future.\
# If possible we will use a Pandas dataframe later

# %%
import pandas as pd

# %%
with open('restaurants.json', 'w' , encoding='utf-8') as w:
    w.write(response.text)

# %%
number_of_restaurants = 0
with open('restaurants.json', 'r', encoding='utf-8') as data_file:
    data = json.load(data_file)
#    for restaurant in data['results']:
#        number_of_restaurants += 1
#        print(restaurant['name'], " -", restaurant['rating'], "☆  |", restaurant['user_ratings_total'], "ratings")

print(data.splitline())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-0ee672ca24cd> in <module>
#       6 #        print(restaurant['name'], " -", restaurant['rating'], "☆  |", restaurant['user_ratings_total'], "ratings")
#       7
# ----> 8 print(data.splitline())
#
# AttributeError: 'dict' object has no attribute 'splitline'
