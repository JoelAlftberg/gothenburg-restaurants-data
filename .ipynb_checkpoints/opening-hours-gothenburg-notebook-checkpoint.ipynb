# %% [markdown]
# # 1. Getting the data

# %%
import requests, json

API_KEY = "AIzaSyCbo3aBXAbhX2hz4GUoWjv1YzVNWkPJbDM"
origin_location = "57.70867542111475,11.973303298399806"
radius_in_meters = "200"
query_string = "thai"

url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={query_string}&type=restaurant&location={origin_location}&radius={radius_in_meters}&key={API_KEY}"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
with open('restaurants.json', 'w') as w:
    w.write(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "Aap_uEADiHKMLvyn_ucEuGVmwebOZ7NyPlq1LEvMfpwWeQAMkn_n6o9jTvzc1vOqKQ6yKAT9hexNXBfQQZSz-OvgxVSkSo_G4aiO8Hvh5vzMTEHrBLQjxiJMd-f8uX9bpaSxKVdoxDl-icK6YU_x-ioBef4Jmr62J4OQlIx87pcIGev332PKQE3rXOCqFLHEaesQpRHgnIdX9LZmLaxDbuG4mV4517gdhXFSuzFMv_2m4QiTJVcV3jZGncSz4NbJ_vvmOnFXRjFEoNgiENiuSp8BOKBlZ416JCuDevplhfLLnHiWGgGEK4GLzWWJBQiyW1XTQ-fCiC_EqDtp3Y4ZYGyMjWjEoJZ6e3hg3g3qVXv_r8zJfRGLuDeHj9LfugAFBTbXXd3GYT0lKEUdhfcw33BQ9RJI33aPXMUbG0-6aeKVaRX0mb5hEhpuw_MSBEaCBM61k8fbFexBBSQ",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Lilla Kyrkogatan 2, 411 15 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.705267,
#                "lng" : 11.965133
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70660272989272,
#                   "lng" : 11.96638072989272
#                },
#                "southwest" : {
#                   "lat" : 57.70390307010727,
#                   "lng" : 11.96368107010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Sukhothai Restaurang",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 994,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/113563256056618679415\"\u003eSukhothai Restaurang\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAQAQliylOwsnU2YiydC0_QUE8DHls1AJlObpjJCd0XZ0q0PLc_SzGTpx4QhUfGH4ZTKj4ojn0QVDra44qlkeeyOZwJQthRsL9qn07RNsZWFVG9RPX9ZtZcfNRiqNbfofDj6uVtgOKOVygSelSpZT_N8I_aFkm5li-Sce4ChsyGNAIz",
#                "width" : 1500
#             }
#          ],
#          "place_id" : "ChIJ6VxndmbzT0YRay3CQXHewis",
#          "plus_code" : {
#             "compound_code" : "PX48+43 Gothenburg",
#             "global_code" : "9F9HPX48+43"
#          },
#          "price_level" : 1,
#          "rating" : 4.1,
#          "reference" : "ChIJ6VxndmbzT0YRay3CQXHewis",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 513
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Kungstorget 14, 411 10 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.70344929999999,
#                "lng" : 11.9691086
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70476862989272,
#                   "lng" : 11.97039057989272
#                },
#                "southwest" : {
#                   "lat" : 57.70206897010728,
#                   "lng" : 11.96769092010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "S.p.i.c.e",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/111654356327665962248\"\u003eRea Castillo\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uED_EfYW4ar6z4YhQtLxXzV8bHfWviZ5kUlXdn2EGGjrO0d05lUZU7io8jPA1OTBmHGfFzaL7OfE2iKkrWdDBclPrLqxnsg-qZRtr3Ov4odrc_pxGOaeHMaNvkhrONIbXkzfI3FHfCaFF1LCR19eBBKypVOOnL0nln9oiH057lbGDS8i",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJVwuKeGXzT0YRN3ziGThQXhc",
#          "plus_code" : {
#             "compound_code" : "PX39+9J Gothenburg",
#             "global_code" : "9F9HPX39+9J"
#          },
#          "price_level" : 2,
#          "rating" : 3.7,
#          "reference" : "ChIJVwuKeGXzT0YRN3ziGThQXhc",
#          "types" : [ "bar", "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 416
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Färgaregatan 4, 411 02 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.70911040000001,
#                "lng" : 11.9832033
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.71046027989274,
#                   "lng" : 11.98443187989272
#                },
#                "southwest" : {
#                   "lat" : 57.70776062010729,
#                   "lng" : 11.98173222010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Niyom Thai",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/110613974109754955290\"\u003eJacob Haskoli\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAhMmkPqutYybCDTeFVD3bBECnblL-CaT1vXxU3Xjv4M3s3fQ0dXNl5pkM6mTSsl3Amjyol8RvFKyMggIMT1qi2TrRGTBuHW_kKTGQYeLrIQagwhz11XiXd02Tj1uIk4iPsNM1OyIVTzvID-5e15xZYHLmfP6pwApMwlM-UNZHq175T",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJo9KFPnzzT0YRbfxCzsT5stA",
#          "plus_code" : {
#             "compound_code" : "PX5M+J7 Gothenburg",
#             "global_code" : "9F9HPX5M+J7"
#          },
#          "rating" : 3.6,
#          "reference" : "ChIJo9KFPnzzT0YRbfxCzsT5stA",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 96
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Stampgatan 46, 411 01 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.70835090000001,
#                "lng" : 11.9862899
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70967582989273,
#                   "lng" : 11.98771407989272
#                },
#                "southwest" : {
#                   "lat" : 57.70697617010728,
#                   "lng" : 11.98501442010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Ullevi Thaikök",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/107128170974483022900\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEBmOuxAuLiMccrIvQuR6JNUbg2n8UWmvDge_dA_U_unH4ONvZs0w9azedZ40Y5-gwy8pmGSqbyff9Bl9lox2MqF_Dhqqs61UZD5szcibeUUUe3uzgtV3Hf26HRJ61kTyIU6M6bjULZ-kA4XQA15wvyD74H5wT2nNQfuvGWedM0kGNbE",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJ8UZUyGfzT0YRYq9e1GLnw9c",
#          "plus_code" : {
#             "compound_code" : "PX5P+8G Gothenburg",
#             "global_code" : "9F9HPX5P+8G"
#          },
#          "rating" : 4.5,
#          "reference" : "ChIJ8UZUyGfzT0YRYq9e1GLnw9c",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 80
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Engelbrektsgatan 51, 412 52 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.69987099999999,
#                "lng" : 11.980431
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70127277989273,
#                   "lng" : 11.98170227989272
#                },
#                "southwest" : {
#                   "lat" : 57.69857312010728,
#                   "lng" : 11.97900262010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Samui Thai Kitchen",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3648,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/111391293552067281461\"\u003eDaniel Källström\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAFoPwrrK9CH7GSk-Khm7pR-cb2gBafhSIeFb2-AbVoJ5QZ9IS3wP0w1mM_FoHWlXxjheGJBO5vEiCT6oPLLGJhaBhSGwFbQXx_2YU6l5GQVlQxYUDOerZ6p0yCpiSPzTU4KS_f7pCE8VRKFw9bNYZyfjfHiz4trGXwqlSxEBPALOh6",
#                "width" : 2736
#             }
#          ],
#          "place_id" : "ChIJUwrozHDzT0YRJQanqaS87Nw",
#          "plus_code" : {
#             "compound_code" : "MXXJ+W5 Gothenburg",
#             "global_code" : "9F9HMXXJ+W5"
#          },
#          "price_level" : 1,
#          "rating" : 4,
#          "reference" : "ChIJUwrozHDzT0YRJQanqaS87Nw",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "store",
#             "establishment"
#          ],
#          "user_ratings_total" : 471
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Mintensgatan 1, 416 63 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.7142476,
#                "lng" : 12.0019456
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.71560952989272,
#                   "lng" : 12.00331797989272
#                },
#                "southwest" : {
#                   "lat" : 57.71290987010727,
#                   "lng" : 12.00061832010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Restaurang Thai Nisa , Mintensgatans Thai Take Away AB",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 2322,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/111746832558391949035\"\u003eRobin Jokinen\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEBXx0LVfgUB8lt4yqr2_ZUYDNRl3mqPdnZomR8fASExdOHDpTerUOW2_QU0rCj5ROqX2yxUFftsXHqvYmQGni0b1rR_IkldjKkScVTYEaTWrQwIa1Sf2NtQyi7scwCJSkmEr7_Ka_Fp-pHHG4uDEJ23sjXvd7q5u-JF3XUvN6VyBVlA",
#                "width" : 4128
#             }
#          ],
#          "place_id" : "ChIJ3S6-4n70T0YRmPXGyZ0pkN0",
#          "plus_code" : {
#             "compound_code" : "P272+MQ Gothenburg",
#             "global_code" : "9F9JP272+MQ"
#          },
#          "price_level" : 2,
#          "rating" : 3.5,
#          "reference" : "ChIJ3S6-4n70T0YRmPXGyZ0pkN0",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 195
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Viktor Rydbergsgatan 42, 412 57 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.6917207,
#                "lng" : 11.9808682
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.69305302989272,
#                   "lng" : 11.98216652989272
#                },
#                "southwest" : {
#                   "lat" : 57.69035337010727,
#                   "lng" : 11.97946687010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Arojj Dii",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3648,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/104254953237281952609\"\u003ecristian ormazabal\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEBXoapt7ip1OzTwK7xQgHyzo-TO-zWzi9G5NLEwMaU3sQ9h9FbgBnHcLoRNT_z501cNcLOsklHPxdgbuemhOel-2a261rSC8rYPTALqpNs_M7c7S-345TxBirfr_TMSscfy8Um8x4bUHwGoG10xpj_wD14HLgrUAeq2yeoeqHAWacLG",
#                "width" : 2736
#             }
#          ],
#          "place_id" : "ChIJX5vM33TzT0YRCyx2D_K0hWg",
#          "plus_code" : {
#             "compound_code" : "MXRJ+M8 Gothenburg",
#             "global_code" : "9F9HMXRJ+M8"
#          },
#          "price_level" : 2,
#          "rating" : 4.4,
#          "reference" : "ChIJX5vM33TzT0YRCyx2D_K0hWg",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 462
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Kristinelundsgatan 9, 411 37 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.6993529,
#                "lng" : 11.975369
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70076437989272,
#                   "lng" : 11.97663182989272
#                },
#                "southwest" : {
#                   "lat" : 57.69806472010728,
#                   "lng" : 11.97393217010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Moon Thai Kitchen",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 2736,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/103472619843458556022\"\u003ewietze klijnstra\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAlxcSGwUTKuFA5AAWXLzYv-xJXd_H7dVti-bLMRAR2Qs2SmkZVUKHbqs8bvDBvQVBdp184Bn84OuQzkG-jwGXOtnA0-i1_Mz1EEwXo7mI3BhqdZTw5xUsCIje4HIo52iVXggZu4wiFo7Vre802AihMrkTkf-FumLav9K5-T3R78-6b",
#                "width" : 4864
#             }
#          ],
#          "place_id" : "ChIJm999q3HzT0YR_lIM-Th8MqM",
#          "plus_code" : {
#             "compound_code" : "MXXG+P4 Gothenburg",
#             "global_code" : "9F9HMXXG+P4"
#          },
#          "price_level" : 2,
#          "rating" : 4.4,
#          "reference" : "ChIJm999q3HzT0YR_lIM-Th8MqM",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 2723
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Föreningsgatan 34, 411 27 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.6965361,
#                "lng" : 11.9704799
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.69785202989272,
#                   "lng" : 11.97190552989272
#                },
#                "southwest" : {
#                   "lat" : 57.69515237010727,
#                   "lng" : 11.96920587010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Toui ́s Thai Kök Vasastan",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 512,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/101196737238586802718\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAmIMmYKsc-jIgZcJa6MpNOi40T8uRxYdn5yu02lb91B3ZFYIirWJcmh8OtmLAtJhf-wt-9qbBPFNDXifju2Jc3H2uippbjsv6k4ulRTv4iKjerGOyZZIf7xwr9pQ10pTsEYvSnQcSXnly6FwC188Pz-A4KDx5nqlia35ZJof9FIYiB",
#                "width" : 664
#             }
#          ],
#          "place_id" : "ChIJm8uR1iDzT0YR1YGd_fHNqLI",
#          "plus_code" : {
#             "compound_code" : "MXWC+J5 Gothenburg",
#             "global_code" : "9F9HMXWC+J5"
#          },
#          "rating" : 4.3,
#          "reference" : "ChIJm8uR1iDzT0YR1YGd_fHNqLI",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 77
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Vasagatan 5C, 411 24 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.69740959999999,
#                "lng" : 11.963754
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.69886402989272,
#                   "lng" : 11.96504932989272
#                },
#                "southwest" : {
#                   "lat" : 57.69616437010728,
#                   "lng" : 11.96234967010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Thai Prayook",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 5504,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/106130141094603525624\"\u003eOlsun\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAbjtJ2LW5lVmS67Cfbb2PweydLXvjUOJdR6Zi6monuYCMak0HqIkuKhuJfixYp2ifOgPvXNvMmbpo8x_feTNZoPad32QAb8VJ0-898CHFv1bmwtKf8xRmCPBrYzl8sd1vjB12BtvF0IJHKHg_8fGbOwhd9fy_PqCITSHsTFPazMUhk",
#                "width" : 3096
#             }
#          ],
#          "place_id" : "ChIJMS6HH2zzT0YRAa-TXK-oxOU",
#          "plus_code" : {
#             "compound_code" : "MXW7+XG Gothenburg",
#             "global_code" : "9F9HMXW7+XG"
#          },
#          "rating" : 3.9,
#          "reference" : "ChIJMS6HH2zzT0YRAa-TXK-oxOU",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 70
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Södra Hamngatan 2, 411 06 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.70700600000001,
#                "lng" : 11.9708752
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70835582989272,
#                   "lng" : 11.97222502989272
#                },
#                "southwest" : {
#                   "lat" : 57.70565617010728,
#                   "lng" : 11.96952537010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Ching Palace",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4000,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/106326097669727434021\"\u003eTerés Bäregård\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uECuuZVneAhlDTtA2kL8GxxgYt2XO6xuelFK9qaWLUkXNoe1aHZbMGrBouSSYH2foLYalieY_mEnrHDFZAIWbwrBBiCruuzm3d31w2kRrJekgx7o_SsGaDDLVgv7rYJf6uhJghvY9YBj9TK2GWevVvrmUEfJf8YzrKkzcTjlsZQvVKS3",
#                "width" : 3000
#             }
#          ],
#          "place_id" : "ChIJBTn_9GTzT0YRD-HDnv0Q2eQ",
#          "plus_code" : {
#             "compound_code" : "PX4C+R9 Gothenburg",
#             "global_code" : "9F9HPX4C+R9"
#          },
#          "rating" : 3.8,
#          "reference" : "ChIJBTn_9GTzT0YRD-HDnv0Q2eQ",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 1382
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Risåsgatan 5, 411 22 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.6944434,
#                "lng" : 11.9563209
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.69576362989272,
#                   "lng" : 11.95763882989272
#                },
#                "southwest" : {
#                   "lat" : 57.69306397010728,
#                   "lng" : 11.95493917010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Totto's Thai Food & Take Away AB",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/107224796125393316838\"\u003eChristoffer Bergenstråhle\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEB4Vm1QknNgEl8RGEvO0yJEjsiOsv1Fqi5rhlfO6CnSkfTtQ48Uk5Z5rswcyJgzHdeRflQkEzqaGNZh8Uf_4-k5JNd1xDfPzj_u8YlBYDefedd77d5O2riTnSuqzq8xPBU5AwAzHfBhUwtrFSml1mnbHB7g1V4qcHwoe_Gh9S551Psp",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJ4eagHmvzT0YRWDLjFY-xcmk",
#          "plus_code" : {
#             "compound_code" : "MXV4+QG Gothenburg",
#             "global_code" : "9F9HMXV4+QG"
#          },
#          "price_level" : 1,
#          "rating" : 4.1,
#          "reference" : "ChIJ4eagHmvzT0YRWDLjFY-xcmk",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 99
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Hjalmar Brantingsgatan 17, 417 18 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.7209838,
#                "lng" : 11.939688
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.72233362989272,
#                   "lng" : 11.94103782989272
#                },
#                "southwest" : {
#                   "lat" : 57.71963397010727,
#                   "lng" : 11.93833817010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Thai Spice",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3000,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/102396432507175802628\"\u003eDavid Lexell\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEDsj9luo4sHYFZdlF25hV4XQe04liri6jEtcQi9Iww8u2Ect4t496Lmx9R7W0kC-Aza7PcN1UWk2xLJQ4raYJBfMqyfv9d9hSAKnvPo25u64jwfziTT1vipWKYlc6yHZzV_QFBAQQLTJSkPUfY2jqq-dKybrdSTaw4yIquKavpUOpMT",
#                "width" : 4000
#             }
#          ],
#          "place_id" : "ChIJrX09Eqn0T0YR2Z4yF3nMJQM",
#          "plus_code" : {
#             "compound_code" : "PWCQ+9V Gothenburg",
#             "global_code" : "9F9HPWCQ+9V"
#          },
#          "price_level" : 1,
#          "rating" : 4,
#          "reference" : "ChIJrX09Eqn0T0YR2Z4yF3nMJQM",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 113
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Brämaregatan 1, 417 04 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.71880739999999,
#                "lng" : 11.9495244
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.72011022989272,
#                   "lng" : 11.95087247989272
#                },
#                "southwest" : {
#                   "lat" : 57.71741057010728,
#                   "lng" : 11.94817282010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Thai Family Kitchen",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 969,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/108410228424765532256\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uECo_wUOdenvezrS3lFWkJKWJH0F6dSIYdu0YI0UCLAABPWjpgCFZOGla9WqIFmc82Jg5x0A0_krGmfIVjgpwsaEJHoMh5QnktxAq7xTgcJ6lIgOTV3bgFGfJ0jeLxPPzuu6WXtFbswhvHWxcssa6HAx6KS4l8y2YZbND2GeCvfW9_d-",
#                "width" : 934
#             }
#          ],
#          "place_id" : "ChIJnRfBqaf0T0YRRL3AOct5lE8",
#          "plus_code" : {
#             "compound_code" : "PW9X+GR Gothenburg",
#             "global_code" : "9F9HPW9X+GR"
#          },
#          "price_level" : 1,
#          "rating" : 4.2,
#          "reference" : "ChIJnRfBqaf0T0YRRL3AOct5lE8",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 91
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Hisingsgatan 21, 417 03 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.71821720000001,
#                "lng" : 11.9452918
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.71956702989272,
#                   "lng" : 11.94664162989272
#                },
#                "southwest" : {
#                   "lat" : 57.71686737010728,
#                   "lng" : 11.94394197010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Tawan Thai Kitchen",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3264,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/113483292683524710511\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uECpCpUqgjNaEfHOhAKBkdng1_ofQgWA33EGkw7rLLVxjkPU6mahtTHhrHgHE-3B_O6LsDlFVF_OYV4Bw_FaZpQVBnsJN2hf0MfcDJPOlkOZEwKvu5OxtCYntOjIdC4rp4ZXVoxmEWegBySE3KaKDmjAypGABPwONHeOmhGk8N6kcN9M",
#                "width" : 2448
#             }
#          ],
#          "place_id" : "ChIJlzGNDnn1T0YRPoAHoBMS8Nc",
#          "plus_code" : {
#             "compound_code" : "PW9W+74 Gothenburg",
#             "global_code" : "9F9HPW9W+74"
#          },
#          "rating" : 4.3,
#          "reference" : "ChIJlzGNDnn1T0YRPoAHoBMS8Nc",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 59
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Andra Långgatan 21, 413 28 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.69913759999999,
#                "lng" : 11.9477361
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.7004874298927,
#                   "lng" : 11.94908592989272
#                },
#                "southwest" : {
#                   "lat" : 57.69778777010726,
#                   "lng" : 11.94638627010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Bangkok Kitchen Göteborg",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/110541134041982491901\"\u003eVi Vo\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEDGqq2F8E_Go8LqZeFRIL1ujBFPe7_YqDWmOSjKuJ_unM4JjGx36Ee0hFBiWfCMIgRfFadAQyGXzMw8sFI9_T0GtQyqUlUQCs1bk7qIa4CbTQHp4eMYUyxt2Rrt0azi92yASTRC71NPPy57td3UgWNfCRYfr0LDieZaD96RoxkEXdZX",
#                "width" : 2268
#             }
#          ],
#          "place_id" : "ChIJE18eY0HzT0YRUmd487GvENM",
#          "plus_code" : {
#             "compound_code" : "MWXX+M3 Gothenburg",
#             "global_code" : "9F9HMWXX+M3"
#          },
#          "price_level" : 2,
#          "rating" : 4.2,
#          "reference" : "ChIJE18eY0HzT0YRUmd487GvENM",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 521
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Utlandagatan 2, 412 82 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.6902836,
#                "lng" : 11.9889803
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.69156902989272,
#                   "lng" : 11.99024957989272
#                },
#                "southwest" : {
#                   "lat" : 57.68886937010728,
#                   "lng" : 11.98754992010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Thaimums Take Away",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4608,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/117613683020449131090\"\u003eRaggeK\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAxgluVaAdIQdO4hywA6FKX_JYRspXs84ZFCRnt_QcIQ3qDfVyJuTumnvD_hawuPQnoPsq-WCPtaet9JeFijDfx1kZ-JkhXqDgHyZab3hld5jnR-XxFwJmBU3KW7U-FXXooS2Sr_hvSegLCwu5pqYmUTxxm6ORoAH90TBYLaCXG_SCp",
#                "width" : 3456
#             }
#          ],
#          "place_id" : "ChIJzzrNnJ_zT0YRiwxCkTJ8v84",
#          "plus_code" : {
#             "compound_code" : "MXRQ+4H Gothenburg",
#             "global_code" : "9F9HMXRQ+4H"
#          },
#          "rating" : 4.3,
#          "reference" : "ChIJzzrNnJ_zT0YRiwxCkTJ8v84",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 112
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Anders Personsgatan 7, 416 48 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.7111644,
#                "lng" : 11.995335
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.71248312989272,
#                   "lng" : 11.99678792989272
#                },
#                "southwest" : {
#                   "lat" : 57.70978347010727,
#                   "lng" : 11.99408827010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Sweet N' Spicy Thai Kitchen",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3264,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/101155348277170035749\"\u003eyasser swed\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEDUWwR4726h7mcJfpmO4m2YpUOrbNONokHSTNzhD0YTp1iDx5c2FAEOhg1VlabGE9juDnlbphbxIRlmmmPJ9wdWaNj3m1TkZ_CtxwJaVkJBZZM3P2gnf6Oa_VAGigHO0S-AXuB7Cm0WP9ePiRHe7FeCYLE8rzYVFfllKLAPAMBA3T7d",
#                "width" : 1836
#             }
#          ],
#          "place_id" : "ChIJvwVHG4DzT0YRrp7Zv2LHtz8",
#          "plus_code" : {
#             "compound_code" : "PX6W+F4 Gothenburg",
#             "global_code" : "9F9HPX6W+F4"
#          },
#          "rating" : 3.7,
#          "reference" : "ChIJvwVHG4DzT0YRrp7Zv2LHtz8",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 86
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Andra Långgatan 24, 413 28 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.69886200000001,
#                "lng" : 11.946816
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70021182989272,
#                   "lng" : 11.94816582989272
#                },
#                "southwest" : {
#                   "lat" : 57.69751217010728,
#                   "lng" : 11.94546617010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Mae Krua",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/118016656947220179303\"\u003eMansoor Pasha\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAglOGDd6hZt8zKOxUuDtql917_1tWpNBlbtNeKDeynCsTAUH997_Vh-1rsYcypWNMrLSZTuWU-7N7gYayhAKLV913ntw2qCRiXa01maVdo6V6Jih0BNrpBNCHRRFSOCA3314REDTb8oru5SILWoTNxCWMOyhQ1RVCyt_2EoFLcfcRd",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJVwEXZ0HzT0YRFKDTeZL2Bzo",
#          "plus_code" : {
#             "compound_code" : "MWXW+GP Gothenburg",
#             "global_code" : "9F9HMWXW+GP"
#          },
#          "price_level" : 2,
#          "rating" : 4,
#          "reference" : "ChIJVwEXZ0HzT0YRFKDTeZL2Bzo",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 151
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Ceresgatan 22, 417 58 Göteborg",
#          "geometry" : {
#             "location" : {
#                "lat" : 57.70792590000001,
#                "lng" : 11.9332213
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 57.70918897989274,
#                   "lng" : 11.93485032989272
#                },
#                "southwest" : {
#                   "lat" : 57.70648932010729,
#                   "lng" : 11.93215067010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Lai Thai Restaurang",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/106288811342741787375\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "Aap_uEAz0HsHGcjEGsjmklj_W7P390I22eyxEXKivKI6W6omV04kOwglPU2OU4EU_LuJZ_unrDSZOXqyIB1p94U40Qgbe-97crpp0Ii0CygvUwfPt2kzavzyxXPSVT25sMPPhLUHLtkJh7yjXH8NX0It2hLnTqKCJPG77ifVCMkpIQaKY3ah",
#                "width" : 1908
#             }
#          ],
#          "place_id" : "ChIJkVvqv1HzT0YRZ89okoWTBws",
#          "plus_code" : {
#             "compound_code" : "PW5M+57 Gothenburg",
#             "global_code" : "9F9HPW5M+57"
#          },
#          "price_level" : 1,
#          "rating" : 4,
#          "reference" : "ChIJkVvqv1HzT0YRZ89okoWTBws",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 196
#       }
#    ],
#    "status" : "OK"
# }
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-33-b9940a2c860e> in <module>
#      15 print(response.text)
#      16 with open('restaurants.json', 'w') as w:
# ---> 17     w.write(response.text)
#
# ~\anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u0301' in position 17057: character maps to <undefined>

# %%
import pandas as pd
