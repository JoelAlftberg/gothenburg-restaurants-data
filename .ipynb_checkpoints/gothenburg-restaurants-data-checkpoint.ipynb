# %% [markdown]
# # 1. Getting the data

# %% [markdown]
# ### The main code for querying the Places API
# After running this the object response will have the json we queried stored in pure text format.\
# Some adjustments will be needed to get more than 20 items from the query, we can do this by using nextPageToken.

# %%
import requests, json
from secretfile import api_key

origin_location = "57.70867542111475,11.973303298399806"
radius_in_meters = 1000
query_string = "burger"

url_textsearch = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={query_string}&type=restaurant&location={origin_location}&radius={radius_in_meters}&key={api_key}"

payload={}
headers = {}

def get_request(url):
    response = requests.request("GET", url, headers=headers, data=payload)
    response.raise_for_status()
    return response

response = get_request(url_textsearch)

# %% [markdown]
# ### Querying for multiple types of restaurants

# %% [markdown]
# Will add code here for getting more results and from all types of restaurants

# %% [markdown]
# ### Formatting the data we just got

# %% [markdown]
# We want to write our results to a file temporarily for convenience, then populate a dataframe with the data.\
# We will use the PlaceID as a foreign key and create two different dataframes, one for the places themselves\
# and one for their opening hours. For the restaurants that don't have opening hours values\
# for a certain day we will want to have the value be "closed".

# %%
with open('restaurants.json', 'w' , encoding='utf-8') as w:
    w.write(response.text)

# %% [markdown]
# There is still some data that we have not been able to catch; the opening hours\
# We will need to iterate through the names in a Place Details query against the Places API

# %%
# The keys function as attributes in this dict
result_dict = {"name": [], "rating": [], "user_ratings_total": [], "formatted_address": [], "place_id": []}

# The keys function as entities in this dict
openinghours_dict = {}

nextpage_token = ""

# Populate the dict with values from the results
with open('restaurants.json', 'r', encoding='utf-8') as data_file:
    data = json.load(data_file)
    for restaurant in data['results']:
        result_dict['place_id'].append(restaurant['place_id'])
        result_dict['name'].append(restaurant['name'])
        result_dict['rating'].append(restaurant['rating'])
        result_dict['user_ratings_total'].append(restaurant['user_ratings_total'])
        result_dict['formatted_address'].append(restaurant['formatted_address'])
    nextpage_token = data['next_page_token']
      
# We query for the opening hours of every restaurant
for place_id in result_dict['place_id']:
    url_findplace = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=opening_hours&key={api_key}"
    response = get_request(url_findplace)
    findplace_data = json.loads(response.text)

    # Since the data we get out form the query
    
    if 'opening_hours' in findplace_data['result']:
        openinghours_dict[place_id] = findplace_data['result']['opening_hours']['weekday_text']
    else:
        openinghours_dict[place_id] = "None"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ace3befdf70d> in <module>
#       9 # Populate the dict with values from the results
#      10 with open('restaurants.json', 'r', encoding='utf-8') as data_file:
# ---> 11     data = json.load(data_file)
#      12     for restaurant in data['results']:
#      13         result_dict['place_id'].append(restaurant['place_id'])
#
# NameError: name 'json' is not defined

# %% [markdown]
# We will need to clean the opening_hours later, for now we will keep them in that format.

# %% [markdown]
# Now that we have the data we need to put it in a dataframe

# %%
import pandas as pd

# %%
# Create a neat dataframe and sort the rows by rating, user_ratings_total
df_places = pd.DataFrame.from_dict(result_dict)
df_places.set_index('place_id')
df_places['rating'] = pd.to_numeric(df_places['rating'])
df_places['user_ratings_total'] = pd.to_numeric(df_places['user_ratings_total'])
df_places.sort_values(['rating', 'user_ratings_total'], ascending=False)
# Out:
#                           name  rating  user_ratings_total  \
# 9   DINÉ Burgers, femman huset     4.7                  30
# 17                    The Barn     4.5                2394
# 7                         2112     4.5                1914
# 11               Master Burger     4.5                  53
# 10  Johnny's Burger and Shakes     4.5                  35
# 1                 DINÉ Burgers     4.4                 927
# 2                         Tugg     4.3                2344
# 0       Stockyard Burger Joint     4.3                 889
# 13            Butcher's Market     4.3                 827
# 16          The Goods Basement     4.3                 120
# 8    The Burger - Beer & Stuff     4.1                 619
# 6      Burger Mansion Göteborg     4.1                 128
# 12                  Burgersson     4.1                  61
# 5                   Burgersson     4.0                 972
# 14                  Burgersson     4.0                 724
# 3              Bastard Burgers     4.0                 522
# 4              Bastard Burgers     4.0                 349
# 15               Linné Burgers     4.0                 117
# 18                     Vigårda     3.8                1178
# 19        Burger King Nordstan     2.9                  94
#
#                                     formatted_address  \
# 9                    Postgatan 26-31, 411 06 Göteborg
# 17                     Kyrkogatan 11, 411 15 Göteborg
# 7                    Magasinsgatan 5, 411 18 Göteborg
# 11                    Södra Vägen 30, 412 54 Göteborg
# 10  Vasa Allen / avenue, Vasagatan 56, 411 36 Göte...
# 1                  Drottninggatan 31, 411 14 Göteborg
# 2                  Drottninggatan 21, 411 14 Göteborg
# 0                       Storgatan 51, 411 38 Göteborg
# 13                      Storgatan 47, 411 38 Göteborg
# 16                Lorensbergsgatan 6, 411 36 Göteborg
# 8                 Andra Långgatan 14, 413 28 Göteborg
# 6         J Sigfrid Edströms gata 10, 416 48 Göteborg
# 12                    Kungstorget 18, 411 17 Göteborg
# 5                    Friggagatan 14B, 411 01 Göteborg
# 14                     Skanstorget 4, 411 22 Göteborg
# 3                 Östra Hamngatan 30, 411 09 Göteborg
# 4                 Södra Larmgatan 11, 411 16 Göteborg
# 15                     Linnégatan 23, 413 04 Göteborg
# 18              Kungsportsavenyen 29, 411 36 Göteborg
# 19                      Postgatan 47, 411 06 Göteborg
#
#                        place_id
# 9   ChIJfXcB_27zT0YRn_cGsJgRclQ
# 17  ChIJK1IOMyqw6UMRzqyaMNgiVds
# 7   ChIJPSytJGbzT0YRKUOpf_qtaeM
# 11  ChIJ2TwN_YvzT0YRBwhJIPkYUD8
# 10  ChIJsfR44DXzT0YRcMekQlC1euw
# 1   ChIJq2LaBCjzT0YRi-8wBQsPM3E
# 2   ChIJt2e12WXzT0YR1mzQqaFk6bc
# 0   ChIJsVTFD3DzT0YRH5WMvE6q5kQ
# 13  ChIJi0nnHnDzT0YRwvhR-xBU36g
# 16  ChIJJYYUL8TzT0YRnSR61ezVPhc
# 8   ChIJ4c2vf0HzT0YRNe6bEJtL_so
# 6   ChIJRZARJXzzT0YRvW3cV1T8eRw
# 12  ChIJiXINC_7zT0YRIGbPo0gpkUQ
# 5   ChIJ-waSFX7zT0YR0B_BWNeYf78
# 14  ChIJbUenCWvzT0YRBfeM7topGRM
# 3   ChIJT_lXYH_zT0YRW104WmLMNzk
# 4   ChIJ22Wom6_zT0YRroSDRonvRPc
# 15  ChIJoWiglM3zT0YR1D8CayyKsjo
# 18  ChIJ3xZMAHHzT0YRk6xfZaiebaw
# 19  ChIJV4q05GbzT0YRiKJJ2YCgCoA

# %%
df_opening_hours = pd.DataFrame.from_dict(openinghours_dict, orient='index')
df_opening_hours
# Out:
#                                                        0  \
# ChIJsVTFD3DzT0YRH5WMvE6q5kQ  Monday: 11:30 AM – 12:00 AM
# ChIJq2LaBCjzT0YRi-8wBQsPM3E   Monday: 11:00 AM – 9:00 PM
# ChIJsfR44DXzT0YRcMekQlC1euw                                             e
# ChIJ2TwN_YvzT0YRBwhJIPkYUD8                 Thursday: 11:30 AM – 10:00 PM
# ChIJiXINC_7zT0YRIGbPo0gpkUQ                  Thursday: 11:00 AM – 2:00 PM
# ChIJi0nnHnDzT0YRwvhR-xBU36g                     Thursday: 5:00 – 10:30 PM
# ChIJbUenCWvzT0YRBfeM7topGRM                      Thursday: 4:30 – 9:30 PM
# ChIJoWiglM3zT0YR1D8CayyKsjo                     Thursday: 4:00 – 11:00 PM
# ChIJJYYUL8TzT0YRnSR61ezVPhc                 Thursday: 11:30 AM – 10:00 PM
# ChIJK1IOMyqw6UMRzqyaMNgiVds                     Thursday: 5:00 – 11:00 PM
# ChIJ3xZMAHHzT0YRk6xfZaiebaw                                             e
# ChIJV4q05GbzT0YRiKJJ2YCgCoA                  Thursday: 10:00 AM – 8:00 PM
#
#                                                                       4  \
# ChIJsVTFD3DzT0YRH5WMvE6q5kQ                  Friday: 11:30 AM – 1:00 AM
# ChIJq2LaBCjzT0YRi-8wBQsPM3E                 Friday: 11:00 AM – 10:00 PM
# ChIJt2e12WXzT0YR1mzQqaFk6bc                 Friday: 11:00 AM – 10:00 PM
# ChIJT_lXYH_zT0YRW104WmLMNzk                 Friday: 11:00 AM – 10:00 PM
# ChIJ22Wom6_zT0YRroSDRonvRPc                    Friday: 12:00 – 10:00 PM
# ChIJ-waSFX7zT0YR0B_BWNeYf78  Friday: 11:00 AM – 1:30 PM, 4:30 – 9:30 PM
# ChIJRZARJXzzT0YRvW3cV1T8eRw                  Friday: 11:00 AM – 9:00 PM
# ChIJPSytJGbzT0YRKUOpf_qtaeM                   Friday: 4:00 PM – 2:00 AM
# ChIJ4c2vf0HzT0YRNe6bEJtL_so                  Friday: 11:00 AM – 1:00 AM
# ChIJfXcB_27zT0YRn_cGsJgRclQ                  Friday: 11:00 AM – 4:00 PM
# ChIJsfR44DXzT0YRcMekQlC1euw                                        None
# ChIJ2TwN_YvzT0YRBwhJIPkYUD8                 Friday: 11:30 AM – 10:00 PM
# ChIJiXINC_7zT0YRIGbPo0gpkUQ                  Friday: 11:00 AM – 2:00 PM
# ChIJi0nnHnDzT0YRwvhR-xBU36g                     Friday: 5:00 – 10:30 PM
# ChIJbUenCWvzT0YRBfeM7topGRM                     Friday: 4:30 – 10:00 PM
# ChIJoWiglM3zT0YR1D8CayyKsjo                     Friday: 4:00 – 11:00 PM
# ChIJJYYUL8TzT0YRnSR61ezVPhc                 Friday: 11:30 AM – 10:00 PM
# ChIJK1IOMyqw6UMRzqyaMNgiVds                  Friday: 5:00 PM – 12:00 AM
# ChIJ3xZMAHHzT0YRk6xfZaiebaw                                        None
# ChIJV4q05GbzT0YRiKJJ2YCgCoA                  Friday: 10:00 AM – 8:00 PM
#
#                                                         5  \
# ChIJsVTFD3DzT0YRH5WMvE6q5kQ  Saturday: 12:00 PM – 1:00 AM
# ChIJq2LaBCjzT0YRi-8wBQsPM3E    Saturday: 12:00 – 10:00 PM
# ChIJt2e12WXzT0YR1mzQqaFk6bc    Saturday: 12:00 – 10:00 PM
# ChIJT_lXYH_zT0YRW104WmLMNzk    Saturday: 12:00 – 10:00 PM
# ChIJ22Wom6_zT0YRroSDRonvRPc    Saturday: 12:00 – 10:00 PM
# ChIJ-waSFX7zT0YR0B_BWNeYf78   Saturday: 9:00 AM – 9:30 PM
# ChIJRZARJXzzT0YRvW3cV1T8eRw  Saturday: 11:00 AM – 9:00 PM
# ChIJPSytJGbzT0YRKUOpf_qtaeM   Saturday: 1:00 PM – 2:00 AM
# ChIJ4c2vf0HzT0YRNe6bEJtL_so  Saturday: 12:00 PM – 1:00 AM
# ChIJfXcB_27zT0YRn_cGsJgRclQ     Saturday: 12:00 – 5:00 PM
# ChIJsfR44DXzT0YRcMekQlC1euw                          None
# ChIJ2TwN_YvzT0YRBwhJIPkYUD8     Saturday: 1:00 – 10:00 PM
# ChIJiXINC_7zT0YRIGbPo0gpkUQ     Saturday: 12:00 – 3:00 PM
# ChIJi0nnHnDzT0YRwvhR-xBU36g    Saturday: 12:00 – 10:30 PM
# ChIJbUenCWvzT0YRBfeM7topGRM  Saturday: 9:00 AM – 10:00 PM
# ChIJoWiglM3zT0YR1D8CayyKsjo    Saturday: 12:00 – 11:00 PM
# ChIJJYYUL8TzT0YRnSR61ezVPhc    Saturday: 12:00 – 10:00 PM
# ChIJK1IOMyqw6UMRzqyaMNgiVds  Saturday: 1:00 PM – 12:00 AM
# ChIJ3xZMAHHzT0YRk6xfZaiebaw                          None
# ChIJV4q05GbzT0YRiKJJ2YCgCoA  Saturday: 11:00 AM – 7:00 PM
#
#                                                       6
# ChIJsVTFD3DzT0YRH5WMvE6q5kQ    Sunday: 12:00 – 11:00 PM
# ChIJq2LaBCjzT0YRi-8wBQsPM3E     Sunday: 12:00 – 7:00 PM
# ChIJt2e12WXzT0YR1mzQqaFk6bc     Sunday: 12:00 – 8:00 PM
# ChIJT_lXYH_zT0YRW104WmLMNzk     Sunday: 12:00 – 8:00 PM
# ChIJ22Wom6_zT0YRroSDRonvRPc     Sunday: 12:00 – 8:00 PM
# ChIJ-waSFX7zT0YR0B_BWNeYf78   Sunday: 9:00 AM – 8:30 PM
# ChIJRZARJXzzT0YRvW3cV1T8eRw  Sunday: 11:00 AM – 9:00 PM
# ChIJPSytJGbzT0YRKUOpf_qtaeM  Sunday: 4:00 PM – 12:00 AM
# ChIJ4c2vf0HzT0YRNe6bEJtL_so              Sunday: Closed
# ChIJfXcB_27zT0YRn_cGsJgRclQ              Sunday: Closed
# ChIJsfR44DXzT0YRcMekQlC1euw                        None
# ChIJ2TwN_YvzT0YRBwhJIPkYUD8     Sunday: 1:00 – 10:00 PM
# ChIJiXINC_7zT0YRIGbPo0gpkUQ              Sunday: Closed
# ChIJi0nnHnDzT0YRwvhR-xBU36g    Sunday: 12:00 – 10:30 PM
# ChIJbUenCWvzT0YRBfeM7topGRM   Sunday: 9:00 AM – 9:00 PM
# ChIJoWiglM3zT0YR1D8CayyKsjo    Sunday: 12:00 – 10:00 PM
# ChIJJYYUL8TzT0YRnSR61ezVPhc     Sunday: 12:00 – 9:00 PM
# ChIJK1IOMyqw6UMRzqyaMNgiVds     Sunday: 1:00 – 10:00 PM
# ChIJ3xZMAHHzT0YRk6xfZaiebaw                        None
# ChIJV4q05GbzT0YRiKJJ2YCgCoA  Sunday: 11:00 AM – 7:00 PM

# %% [markdown]
# ### Storing the data
